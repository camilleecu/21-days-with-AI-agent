# %%
import sys

from dotenv import load_dotenv
load_dotenv()
from google import genai

from ingest import load_faq_data, build_index
from rag_helper import RAGBase

google_client = genai.Client()
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.

# %% [markdown]
# a small web interface. We use Streamlit, a Python framework for building front ends with almost no code.

# %%
import streamlit as st
sys.path.append("/workspaces/21-days-with-AI-agent/llm-zoomcamp-code/ch5_code")
from assistant import create_assistant

assistant = create_assistant()

st.title("Course Assistant")

user_input = st.text_input("Enter your question:")

if st.button("Ask"):
    with st.spinner("Processing..."):
        answer = assistant.rag(user_input)
        st.success("Completed!")
        st.write(answer)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# Using timezone: UTC
# 2026-07-04 09:09:51.757 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-04 09:09:52.540
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /workspaces/21-days-with-AI-agent/llm-zoomcamp-code/agentvenv/lib/python3.12/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2026-07-04 09:09:52.541 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-04 09:09:52.542 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-04 09:09:52.542 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-04 09:09:52.543 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-04 09:09:52.544 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-04 09:09:52.544 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-04 09:09:52.545 Session state does not function when running a script without `streamlit run`
# 2026-07-04 09:09:52.546 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-04 09:09:52.546 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-04 09:09:52.547 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-04 09:09:52.548 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-04 09:09:52.548 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-04 09:09:52.549 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-04 09:09:52.550 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-04 09:09:52.550 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-04 09:09:52.551 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
